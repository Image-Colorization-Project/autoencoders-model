# %%
#Colorization autoencoder
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
# Out:
# C:\Users\Mudit\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def rgb2gray(rgb):
    """Convert from color image (RGB) to grayscale.
       Source: opencv.org
       grayscale = 0.299*red + 0.587*green + 0.114*blue
    Argument:
        rgb (tensor): rgb image
    Return:
        (tensor): grayscale image
    """
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
# load the CIFAR10 data
(x_train, _), (x_test, _) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 685s 4us/step

# %%
img_rows = x_train.shape[1]
img_cols = x_train.shape[2]
channels = x_train.shape[3]

# %%
x_test[:1,:,:,:]
# Out:
# array([[[[158, 112,  49],
#          [159, 111,  47],
#          [165, 116,  51],
#          ...,
#          [137,  95,  36],
#          [126,  91,  36],
#          [116,  85,  33]],
#
#         [[152, 112,  51],
#          [151, 110,  40],
#          [159, 114,  45],
#          ...,
#          [136,  95,  31],
#          [125,  91,  32],
#          [119,  88,  34]],
#
#         [[151, 110,  47],
#          [151, 109,  33],
#          [158, 111,  36],
#          ...,
#          [139,  98,  34],
#          [130,  95,  34],
#          [120,  89,  33]],
#
#         ...,
#
#         [[ 68, 124, 177],
#          [ 42, 100, 148],
#          [ 31,  88, 137],
#          ...,
#          [ 38,  97, 146],
#          [ 13,  64, 108],
#          [ 40,  85, 127]],
#
#         [[ 61, 116, 168],
#          [ 49, 102, 148],
#          [ 35,  85, 132],
#          ...,
#          [ 26,  82, 130],
#          [ 29,  82, 126],
#          [ 20,  64, 107]],
#
#         [[ 54, 107, 160],
#          [ 56, 105, 149],
#          [ 45,  89, 132],
#          ...,
#          [ 24,  77, 124],
#          [ 34,  84, 129],
#          [ 21,  67, 110]]]], dtype=uint8)

# %%
# create saved_images folder
imgs_dir = 'saved_images'
save_dir = os.path.join(os.getcwd(), imgs_dir)
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)

# %%
# display the 1st 100 input images (color and gray)
imgs = x_test[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test color images (Ground  Truth)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/test_color.png' % imgs_dir)
plt.show()

# %%
# convert color train and test images to gray
x_train_gray = rgb2gray(x_train)
x_test_gray = rgb2gray(x_test)

# %%
# display grayscale version of test images
imgs = x_test_gray[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test gray images (Input)')
plt.imshow(imgs, interpolation='none', cmap='gray')
plt.savefig('%s/test_gray.png' % imgs_dir)
plt.show()

# %%
# normalize output train and test color images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# normalize input train and test grayscale images
x_train_gray = x_train_gray.astype('float32') / 255
x_test_gray = x_test_gray.astype('float32') / 255

# %%
#x_train.shape
channels
# Out:
# 3

# %%
# reshape images to row x col x channel for CNN output/validation
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)

# %%
# reshape images to row x col x channel for CNN input
x_train_gray = x_train_gray.reshape(x_train_gray.shape[0], img_rows, img_cols, 1)
x_test_gray = x_test_gray.reshape(x_test_gray.shape[0], img_rows, img_cols, 1)

# %%
# network parameters
input_shape = (img_rows, img_cols, 1)
batch_size = 32
kernel_size = 3
latent_dim = 256
# encoder/decoder number of CNN layers and filters per layer
layer_filters = [64, 128, 256] #Specifies size of successive convolutional layers in the encoderpart of the model

# %%
# build the autoencoder model
# first build the encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
# stack of Conv2D(64)-Conv2D(128)-Conv2D(256)
for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=2,
               activation='relu',
               padding='same')(x)

# %%
# shape info needed to build decoder model so we don't do hand computation
# the input to the decoder's first Conv2DTranspose will have this shape
# shape is (4, 4, 256) which is processed by the decoder back to (32, 32, 3)
shape = K.int_shape(x)

# %%
# generate a latent vector
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)

# %%
# instantiate encoder model
encoder = Model(inputs, latent, name='encoder')
encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               1048832
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# build the decoder model
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)

# %%
# stack of Conv2DTranspose(256)-Conv2DTranspose(128)-Conv2DTranspose(64)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        strides=2,
                        activation='relu',
                        padding='same')(x)

# %%
outputs = Conv2DTranspose(filters=channels,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# %%
# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       295040
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 64)        73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 32, 32, 3)         1731
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 32, 32, 1)         0
# _________________________________________________________________
# encoder (Model)              (None, 256)               1418496
# _________________________________________________________________
# decoder (Model)              (None, 32, 32, 3)         2013315
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
# prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# reduce learning rate by sqrt(0.1) if the loss does not improve in 5 epochs
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# %%
# save weights for future use (e.g. reload parameters w/o training)
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

# %%
# Mean Square Error (MSE) loss function, Adam optimizer
autoencoder.compile(loss='mse', optimizer='adam')

# %%
# called every epoch
callbacks = [lr_reducer, checkpoint]

# %%
# train the autoencoder
autoencoder.fit(x_train_gray,
                x_train,
                validation_data=(x_test_gray, x_test),
                epochs=30,
                batch_size=batch_size,
                callbacks=callbacks)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.4889
# Epoch 00001: val_loss improved from inf to 0.36501, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.001.h5
# 50000/50000 [==============================] - 234s 5ms/step - loss: 0.4888 - val_loss: 0.3650
# Epoch 2/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.3293
# Epoch 00002: val_loss improved from 0.36501 to 0.30808, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.002.h5
# 50000/50000 [==============================] - 190s 4ms/step - loss: 0.3293 - val_loss: 0.3081
# Epoch 3/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2983
# Epoch 00003: val_loss improved from 0.30808 to 0.28242, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.003.h5
# 50000/50000 [==============================] - 191s 4ms/step - loss: 0.2982 - val_loss: 0.2824
# Epoch 4/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2788
# Epoch 00004: val_loss improved from 0.28242 to 0.27797, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.004.h5
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.2788 - val_loss: 0.2780
# Epoch 5/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2655
# Epoch 00005: val_loss improved from 0.27797 to 0.26595, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.005.h5
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.2654 - val_loss: 0.2660
# Epoch 6/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2551
# Epoch 00006: val_loss improved from 0.26595 to 0.25933, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.006.h5
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.2551 - val_loss: 0.2593
# Epoch 7/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2467
# Epoch 00007: val_loss improved from 0.25933 to 0.25336, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.007.h5
# 50000/50000 [==============================] - 209s 4ms/step - loss: 0.2467 - val_loss: 0.2534
# Epoch 8/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2386
# Epoch 00008: val_loss did not improve from 0.25336
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.2386 - val_loss: 0.2624
# Epoch 9/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2318
# Epoch 00009: val_loss improved from 0.25336 to 0.25010, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.009.h5
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.2318 - val_loss: 0.2501
# Epoch 10/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2243
# Epoch 00010: val_loss improved from 0.25010 to 0.24407, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.010.h5
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.2242 - val_loss: 0.2441
# Epoch 11/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2172
# Epoch 00011: val_loss did not improve from 0.24407
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.2171 - val_loss: 0.2585
# Epoch 12/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2101
# Epoch 00012: val_loss did not improve from 0.24407
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.2101 - val_loss: 0.2480
# Epoch 13/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.2025
# Epoch 00013: val_loss did not improve from 0.24407
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.2025 - val_loss: 0.2462
# Epoch 14/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1958
# Epoch 00014: val_loss did not improve from 0.24407
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.1958 - val_loss: 0.2491
# Epoch 15/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1891
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00015: val_loss did not improve from 0.24407
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.1891 - val_loss: 0.2543
# Epoch 16/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1634
# Epoch 00016: val_loss improved from 0.24407 to 0.24086, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.016.h5
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1634 - val_loss: 0.2409
# Epoch 17/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1557
# Epoch 00017: val_loss improved from 0.24086 to 0.24073, saving model to C:\Users\Mudit\Documents\FINAL-SEM\open-src-code\saved_models\colorized_ae_model.017.h5
# 50000/50000 [==============================] - 197s 4ms/step - loss: 0.1556 - val_loss: 0.2407
# Epoch 18/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1511
# Epoch 00018: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 196s 4ms/step - loss: 0.1511 - val_loss: 0.2422
# Epoch 19/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1470
# Epoch 00019: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 193s 4ms/step - loss: 0.1470 - val_loss: 0.2413
# Epoch 20/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1434
# Epoch 00020: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1433 - val_loss: 0.2446
# Epoch 21/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1402
# Epoch 00021: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1402 - val_loss: 0.2492
# Epoch 22/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1373
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00022: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1373 - val_loss: 0.2447
# Epoch 23/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1288
# Epoch 00023: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1288 - val_loss: 0.2474
# Epoch 24/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1269
# Epoch 00024: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 193s 4ms/step - loss: 0.1268 - val_loss: 0.2475
# Epoch 25/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1256
# Epoch 00025: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 191s 4ms/step - loss: 0.1256 - val_loss: 0.2483
# Epoch 26/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1244
# Epoch 00026: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1244 - val_loss: 0.2486
# Epoch 27/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1234
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 00027: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 193s 4ms/step - loss: 0.1234 - val_loss: 0.2476
# Epoch 28/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1205
# Epoch 00028: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1205 - val_loss: 0.2495
# Epoch 29/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1200
# Epoch 00029: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1200 - val_loss: 0.2496
# Epoch 30/30
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.1196
# Epoch 00030: val_loss did not improve from 0.24073
# 50000/50000 [==============================] - 192s 4ms/step - loss: 0.1196 - val_loss: 0.2496

# %%
# predict the autoencoder output from test data
x_decoded = autoencoder.predict(x_test_gray)

# %%
# display the 1st 100 colorized images
imgs = x_decoded[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()

# %%
imgs = x_decoded[:25]
imgs = imgs.reshape((5, 5, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('First 25 Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()
